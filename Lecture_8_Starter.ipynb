# %% [markdown]
# # Division A

# %%
div_a_scores_dictionary = {"student_name": ["Jay", "Aaryan", "Sahil","Riya","Shubh"],
                         "math_scores": [20,56,76,78,90],
                         "chemistry_scores": [32,36,78,23,100],
                         "information_technology_scores": [34,6,88,100,45],
                         "physics_scores": [6,88,48,90,25]
                         }

# %%
div_a_emails_dictionary = {"student_name": ["Jay", "Aaryan", "Sahil","Riya","Shubh"],
                           "student_email": ["Jay@gmail.com", "Aaryan@gmail.com", "Sahil@gmail.com","Riya@gmail.com","Shubh@gmail.com"]
                         }

# %% [markdown]
# # Division B

# %%
div_b_scores_dictionary = {"student_name": ["Jai", "Aryan", "Firoz","Steve","Rhea"],
                         "math_scores": [32,56,76,78,90],
                         "chemistry_scores": [32,56,75,23,10],
                         "information_technology_scores": [34,6,48,100,45],
                         "physics_scores": [6,88,58,90,25]
                         }

# %%
div_b_emails_dictionary = {"student_name": ["Jai", "Aryan", "Firoz","Steve","Rhea"],
                            "student_email": ["Jai@gmail.com", "Aryan@gmail.com", "Firoz@gmail.com","Steve@gmail.com","Rhea@gmail.com"]
                         }

# %% [markdown]
# # Division C

# %%
div_c_scores_dictionary = {"student_name": ["Kareena", "Alia", "Priyanka","Shahrukh","Salman"],
                         "math_scores": [22,56,76,78,90],
                         "chemistry_scores": [30,56,78,23,100],
                         "information_technology_scores": [34,6,98,100,40],
                         "physics_scores": [60,88,58,90,25]
                         }

# %%
div_c_emails_dictionary = {"student_name": ["Kareena", "Alia", "Priyanka","Shahrukh","Salman"],
                            "student_email": ["Kareena@gmail.com", "Alia@gmail.com", "Priyanka@gmail.com","Shahrukh@gmail.com","Salman@gmail.com"]
                         }

# %% [markdown]
# # Functions

# %%
# Setup 
import pandas as pd

# %%
# Get Scores is a function that accepts a report card dictionary and a division name
# Converts the dictionary into a dataframe, adds additional columns
# And Returns the report card as dataframe 

def get_scores(report_card_dictionary, division_name): 
    
    # Convert the dictionary into a dataframe
    report_card_df = pd.DataFrame(report_card_dictionary)
    
    # Add a column called Division (e.g A, B, C)
    report_card_df["division"] = division_name
    
    # Add a column called Total Score (0 to 400)
    report_card_df["total_score"] = report_card_df["math_scores"] + report_card_df["chemistry_scores"] + report_card_df["physics_scores"] + report_card_df["information_technology_scores"]
    
    # Add a column called Average Score (0 to 100)
    report_card_df["average_score"] = report_card_df["total_score"]/4
    
    # Add a column called Status (Pass or Fail)
    report_card_df.loc[report_card_df["average_score"] >=35, "status"] = "pass"
    report_card_df.loc[report_card_df["average_score"] <35, "status"] = "fail"
    
  
    # Add character grade column(A, B, C, D, F)
    report_card_df.loc[report_card_df["average_score"]>=90, "character_grade"] = "A"
    report_card_df.loc[(report_card_df["average_score"]>=70) & (report_card_df["average_score"]<90),"character_grade"] = "B"
    report_card_df.loc[(report_card_df["average_score"]>=50) & (report_card_df["average_score"]<70),"character_grade"] = "C"
    report_card_df.loc[(report_card_df["average_score"]>=35) & (report_card_df["average_score"]<50),"character_grade"] = "D"
    report_card_df.loc[report_card_df["average_score"]<35, "character_grade"] = "F" 

    # Return the dataframe
    return report_card_df

# %%
division_a_report_card_df = get_scores(div_a_scores_dictionary,"A")
division_a_report_card_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0          Jay           20                32                             34
# 1       Aaryan           56                36                              6
# 2        Sahil           76                78                             88
# 3         Riya           78                23                            100
# 4        Shubh           90               100                             45
#
#    physics_scores division  total_score  average_score status character_grade
# 0               6        A           92          23.00   fail               F
# 1              88        A          186          46.50   pass               D
# 2              48        A          290          72.50   pass               B
# 3              90        A          291          72.75   pass               B
# 4              25        A          260          65.00   pass               C

# %% [markdown]
# ## Get Emails Function

# %%
# Get Emails is a function that accepts a dictionary and a division name
# and converts the dictionary into a dataframe, adds a column, converts all emails to lowercase
# and returns the dataframe

def get_emails(emails_dictionary, division_name):
    
    #Converting the dictionary into a dataframe
    emails_df = pd.DataFrame(emails_dictionary)
    
    #Creating a column called Division
    emails_df["division"] = division_name
    
    #Converting all String Values in the Student Email Column to Lower Case
    emails_df["student_email"] = emails_df["student_email"].str.lower()
    
    #Return the dataframe
    return emails_df

# %%
div_a_emails_df = get_emails(div_a_emails_dictionary, "A")
div_a_emails_df
# Out:
#   student_name     student_email division
# 0          Jay     jay@gmail.com        A
# 1       Aaryan  aaryan@gmail.com        A
# 2        Sahil   sahil@gmail.com        A
# 3         Riya    riya@gmail.com        A
# 4        Shubh   shubh@gmail.com        A

# %% [markdown]
# ## Get Scores and Email Function

# %%
def get_scores_and_emails_combined(report_card_df, emails_df):
    report_card_with_emails_df = pd.merge(report_card_df, emails_df, how = "left", on = ["student_name","division"])
    return report_card_with_emails_df

# %% [markdown]
# # Get All Divisions Scoresheet

# %%
div_a_scores_df = get_scores(div_a_scores_dictionary, "A")
div_a_emails_df = get_emails(div_a_emails_dictionary, "A")
div_a_combined_df = get_scores_and_emails_combined(div_a_scores_df, div_a_emails_df)
div_a_combined_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0          Jay           20                32                             34
# 1       Aaryan           56                36                              6
# 2        Sahil           76                78                             88
# 3         Riya           78                23                            100
# 4        Shubh           90               100                             45
#
#    physics_scores division  total_score  average_score status character_grade  \
# 0               6        A           92          23.00   fail               F
# 1              88        A          186          46.50   pass               D
# 2              48        A          290          72.50   pass               B
# 3              90        A          291          72.75   pass               B
# 4              25        A          260          65.00   pass               C
#
#       student_email
# ...

# %%
div_b_scores_df = get_scores(div_b_scores_dictionary, "B")
div_b_emails_df = get_emails(div_b_emails_dictionary, "B")
div_b_combined_df = get_scores_and_emails_combined(div_b_scores_df, div_b_emails_df)
div_b_combined_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0          Jai           32                32                             34
# 1        Aryan           56                56                              6
# 2        Firoz           76                75                             48
# 3        Steve           78                23                            100
# 4         Rhea           90                10                             45
#
#    physics_scores division  total_score  average_score status character_grade  \
# 0               6        B          104          26.00   fail               F
# 1              88        B          206          51.50   pass               C
# 2              58        B          257          64.25   pass               C
# 3              90        B          291          72.75   pass               B
# 4              25        B          170          42.50   pass               D
#
#      student_email
# ...

# %%
div_c_scores_df = get_scores(div_c_scores_dictionary, "C")
div_c_emails_df = get_emails(div_c_emails_dictionary, "C")
div_c_combined_df = get_scores_and_emails_combined(div_c_scores_df, div_c_emails_df)
div_c_combined_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0      Kareena           22                30                             34
# 1         Alia           56                56                              6
# 2     Priyanka           76                78                             98
# 3     Shahrukh           78                23                            100
# 4       Salman           90               100                             40
#
#    physics_scores division  total_score  average_score status character_grade  \
# 0              60        C          146          36.50   pass               D
# 1              88        C          206          51.50   pass               C
# 2              58        C          310          77.50   pass               B
# 3              90        C          291          72.75   pass               B
# 4              25        C          255          63.75   pass               C
#
#         student_email
# ...

# %%
def get_all_divisions_scoresheet(div_a_df, div_b_df, div_c_df):
    all_divisions_df = pd.concat([div_a_df, div_b_df, div_c_df], ignore_index = True)
    return all_divisions_df

# %%
main_grade_sheet = get_all_divisions_scoresheet(div_a_combined_df, div_b_combined_df, div_c_combined_df)
main_grade_sheet.to_csv("Main Grade Sheet.csv")
